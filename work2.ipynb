# %%
import requests 
from datetime import date,datetime
import re 
import os
from lxml import etree
import jieba
import collections
import pyecharts.options as opts
from pyecharts.commons.utils import JsCode
from pyecharts.charts import Bar3D,Line,Scatter,Pie,Tab,WordCloud,Page
from pyecharts.globals import SymbolType

# %%
#网页爬取模块ss 
def get_html(url,Folder='default',postifix='',cookie=''):
    try:
        headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.74 Safari/537.36',
        'Cookie':cookie
       }
        #使用国外代理
        proxies={'http':'http://127.0.0.1:7890','https':'http://127.0.0.1:7890'}
        #get请求获取界面
        url = requests.get(url,headers=headers,proxies=proxies)
        #转码为utf-8
        url.encoding = url.apparent_encoding
        #推导存放路径
        path = './'+Folder+'/'+Folder+postifix+".html"
        #写入文件
        with open(path,"wb") as f:
            f.write(url.content)
            f.close()
    except Exception as e :
        print(e)
    return "ok111"

# %%
#时间获取模块
def get_today_data():
    cur_time = datetime.now()
    time = datetime.strftime(cur_time,'%m_%d')#格式化时间字符串
    return time

# %%
#网页爬取操作区
today = get_today_data()
stackoverflow_cookie = ''
github_cookie = ''
get_html('https://stackoverflow.com/?tab=hot','stackoverflow','_'+today,stackoverflow_cookie)
get_html('https://github.com/trending?since=daily','github_today','_'+today,github_cookie)
# Out:
# 'ok'

# %%
#测试区
today = get_today_data()
print(today)
# get_html('https://stackoverflow.com/?tab=hot','stackoverflow','_'+today)
# Out:
# 05_25

# %%
#本地文件夹文件名提取模块
def get_path(Folder_name):
    path = os.path.abspath('.')
    path_list=os.listdir(str(path)+"\\"+str(Folder_name))
    return path_list

# %%
#github网页数据过滤-分模块
def analyze_github(html,time):
    data = []
    #每一页有25个项目，用xpath索引查找
    for i in range(1,25):
        #定义一个字典存放 
        # time时间,title标题
        # text摘要,tages使用的编程语言
        dict={}
        # time就是传入的时间
        dict["time"]=time
        #xpath获取标题
        titles = html.xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article['+str(i)+']/h1/a/text()')
        #去除前后的换行和空格
        title = titles[2].strip('\n').strip(' ').strip('\n')
        dict["title"]=title
        #xpath获取摘要
        text = html.xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article['+str(i)+']/p//text()')
        #摘要可能出现空或者非空，特殊判断下，并去除前后的换行和空格
        if len(text) >=1:
            dict["text"]=text[0].strip('\n').strip(' ').strip('\n')
        else :
            dict["text"]=''
        tag = html.xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article['+str(i)+']/div[2]/span[1]/span[2]//text()')
        #语言标签可能出现空或者非空，特殊判断下，并去除前后的换行和空格
        if len(tag) >=1 :
            dict["tags"]=[]
            dict["tags"].append(tag[0])
        else :
            dict["tags"]=[]
        data.append(dict)
    return data

# %%
#stackoverflow网页数据过滤-分模块
def analyze_stackoverflow(html,time):
        data = []
        # re匹配全部热榜问题
        text_all = re.findall('\"([0-9]*)\" data-post-type-id=\"1\">([\s\S]*?)</time>',html,re.S)
        # 将每个问题拆分出来，对问题的id和时间和语言标签进行提取
        for text in text_all:
                #定义一个字典存放 
                # time时间,title标题
                # id 问题id,tage 关键词标签
                dict = {}
                dict["time"]=time
                dict["id"]=eval(text[0])
                dict["tags"]=[]
                # 匹配标题
                titles = re.findall('class=\"s-link\">(.*?)</a>',text[1],re.S)
                dict["title"]=titles[0]
                # 匹配标签
                tags = re.findall('rel=\"tag\">([a-z-+0-9#.]*)',text[1],re.S)
                for tag in tags:
                        dict["tags"].append(tag)
                data.append(dict)
        return data

# %%
#分析网页-总模块
def analyze_html(name):
    datas = []
    #读取网站名称，获取他目录下的页面名称列表
    paths_lists = get_path(name)
    for path in paths_lists:
        # 通过字符串处理得到爬取的时间
        time = path.replace(name+"_","").replace(".html","")
        # 传入github分支
        if name.find("github") != -1:
            # 进行etree结构化，使其能被xpath分析
            html = etree.parse(name+'/'+path,etree.HTMLParser())
            data = analyze_github(html,time)
        # 传入Stack Overflow分支
        if name == 'stackoverflow':
            #读取html，re库直接源码匹配即可
            html = open(name+'/'+path,"r",encoding="utf-8").read()
            data = analyze_stackoverflow(html,time)
        for iter in data:
            # 将传出的数据进行汇总到datas中
            datas.append(iter)
    return datas

# %%
#数据分析调用区
# get_path('github_monthly')
stackoverflow_datas = analyze_html('stackoverflow')
github_today_datas = analyze_html('github_today')
github_today_datas
# print(github_today_datas)
# github_week_datas = analyze_html('github_week')
# github_monthly_datas = analyze_html('github_monthly')
# stackoverflow_datas = analyze_html('stackoverflow')
# for data in datas:
#     print(data)
# Out:
# [{'time': '05_06',
#   'title': 'metaseq',
#   'text': 'Repo for external large-scale work',
#   'tags': ['Python']},
#  {'time': '05_06',
#   'title': 'tmagic-editor',
#   'text': '',
#   'tags': ['TypeScript']},
#  {'time': '05_06',
#   'title': 'Microsoft-3D-Movie-Maker',
#   'text': 'This is the source code for the original Microsoft 3D Movie Maker released in 1995. This is not supported software.',
#   'tags': ['SWIG']},
#  {'time': '05_06',
#   'title': 'zhao',
#   'text': '【编程随想】整理的《太子党关系网络》，专门揭露赵国的权贵',
#   'tags': ['Python']},
#  {'time': '05_06',
#   'title': 'gin',
#   'text': 'Gin is a HTTP web framework written in Go (Golang). It features a Martini-like API with much better performance -- up to 40 times faster. If you need smashing performance, get yourself some Gin.',
#   'tags': ['Go']},
#  {'time': '05_06',
#   'title': 'deep-rl-class',
#   'text': 'This repo contain the syllabus of the Hugging Face Deep Reinforcement Learning Class.',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_06',
#   'title': 'freeCodeCamp',
#   'text': "freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free.",
#   'tags': ['TypeScript']},
#  {'time': '05_06',
#   'title': 'Digital-Forensics-Guide',
#   'text': 'Digital Forensics Guide',
#   'tags': ['Python']},
#  {'time': '05_06', 'title': 'pyscript', 'text': '', 'tags': ['HTML']},
#  {'time': '05_06',
#   'title': 'JavaGuide',
#   'text': '「Java学习+面试指南」一份涵盖大部分 Java 程序员所需要掌握的核心知识。准备 Java 面试，首选 JavaGuide！',
#   'tags': ['Java']},
#  {'time': '05_06',
#   'title': 'GitHubGraduation-2022',
#   'text': 'Join the GitHub Graduation Yearbook and "walk the stage" on June 11.',
#   'tags': ['JavaScript']},
#  {'time': '05_06',
#   'title': 'mvt',
#   'text': 'MVT (Mobile Verification Toolkit) helps with conducting forensics of mobile devices in order to find signs of a potential compromise.',
#   'tags': ['Python']},
#  {'time': '05_06',
#   'title': 'Awesome-GitHub-Repo',
#   'text': '收集整理 GitHub 上高质量、有趣的开源项目。',
#   'tags': []},
#  {'time': '05_06',
#   'title': 'pdf',
#   'text': '编程电子书，电子书，编程书籍，包括C，C#，Docker，Elasticsearch，Git，Hadoop，HeadFirst，Java，Javascript，jvm，Kafka，Linux，Maven，MongoDB，MyBatis，MySQL，Netty，Nginx，Python，RabbitMQ，Redis，Scala，Solr，Spark，Spring，SpringBoot，SpringCloud，TCPIP，Tomcat，Zookeeper，人工智能，大数据类，并发编程，数据库类，数据挖掘，新面试题，架构设计，算法系列，计算机类，设计模式，软件测试，重构优化，等更多分类',
#   'tags': []},
#  {'time': '05_06',
#   'title': 'aptos-core',
#   'text': 'A layer 1 for everyone!',
#   'tags': ['Rust']},
#  {'time': '05_06', 'title': 'go-by-example', 'text': '', 'tags': ['Go']},
#  {'time': '05_06',
#   'title': 'holoiso',
#   'text': 'SteamOS 3 (Holo) archiso configuration',
#   'tags': ['Shell']},
#  {'time': '05_06', 'title': 'arcticdb', 'text': '', 'tags': ['Go']},
#  {'time': '05_06',
#   'title': 'element',
#   'text': 'A Vue.js 2.0 UI Toolkit for Web',
#   'tags': ['Vue']},
#  {'time': '05_06',
#   'title': 'Grasscutter',
#   'text': 'A server software reimplementation for a certain anime game.',
#   'tags': ['Java']},
#  {'time': '05_06',
#   'title': 'docs',
#   'text': 'This repository contains .NET Documentation.',
#   'tags': []},
#  {'time': '05_06',
#   'title': 'Geographical-Adventures',
#   'text': '',
#   'tags': ['C#']},
#  {'time': '05_06',
#   'title': 'metersphere',
#   'text': 'MeterSphere 是一站式开源持续测试平台，覆盖测试管理、接口测试、UI 测试和性能测试等。搞测试，就选 MeterSphere！',
#   'tags': ['Java']},
#  {'time': '05_06',
#   'title': 'free-programming-books-zh_CN',
#   'text': '',
#   'tags': []},
#  {'time': '05_07',
#   'title': 'FUCK-GFW',
#   'text': '记录各个包管理器使用代理的方法, 因为GFW已经浪费了已经数不清的时间, FUCK GFW',
#   'tags': []},
#  {'time': '05_07',
#   'title': 'tmagic-editor',
#   'text': '',
#   'tags': ['TypeScript']},
#  {'time': '05_07',
#   'title': 'rustdesk',
#   'text': 'Yet another remote desktop software',
#   'tags': ['Rust']},
#  {'time': '05_07',
#   'title': 'deno',
#   'text': 'A modern runtime for JavaScript and TypeScript.',
#   'tags': ['Rust']},
#  {'time': '05_07',
#   'title': 'easyexcel',
#   'text': '快速、简洁、解决大文件内存溢出的java处理Excel工具',
#   'tags': ['Java']},
#  {'time': '05_07',
#   'title': 'gogs',
#   'text': 'Gogs is a painless self-hosted Git service',
#   'tags': ['Go']},
#  {'time': '05_07',
#   'title': 'vscode',
#   'text': 'Visual Studio Code',
#   'tags': ['TypeScript']},
#  {'time': '05_07', 'title': 'go-by-example', 'text': '', 'tags': ['Go']},
#  {'time': '05_07',
#   'title': 'aptos-core',
#   'text': 'A layer 1 for everyone!',
#   'tags': ['Rust']},
#  {'time': '05_07',
#   'title': 'dive',
#   'text': 'A tool for exploring each layer in a docker image',
#   'tags': ['Go']},
#  {'time': '05_07',
#   'title': 'cloudsploit',
#   'text': 'Cloud Security Posture Management (CSPM)',
#   'tags': ['JavaScript']},
#  {'time': '05_07',
#   'title': 'cs-video-courses',
#   'text': 'List of Computer Science courses with video lectures.',
#   'tags': []},
#  {'time': '05_07',
#   'title': 'foundry',
#   'text': 'Foundry is a blazing fast, portable and modular toolkit for Ethereum application development written in Rust.',
#   'tags': ['Rust']},
#  {'time': '05_07',
#   'title': 'holoiso',
#   'text': 'SteamOS 3 (Holo) archiso configuration',
#   'tags': ['Shell']},
#  {'time': '05_07',
#   'title': 'metersphere',
#   'text': 'MeterSphere 是一站式开源持续测试平台，覆盖测试管理、接口测试、UI 测试和性能测试等。搞测试，就选 MeterSphere！',
#   'tags': ['Java']},
#  {'time': '05_07', 'title': 'clash-tracing', 'text': '', 'tags': ['Go']},
#  {'time': '05_07',
#   'title': 'free-programming-books-zh_CN',
#   'text': '',
#   'tags': []},
#  {'time': '05_07',
#   'title': 'mlops-zoomcamp',
#   'text': 'Free MLOps course from DataTalks.Club',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_07',
#   'title': 'JavaGuide',
#   'text': '「Java学习+面试指南」一份涵盖大部分 Java 程序员所需要掌握的核心知识。准备 Java 面试，首选 JavaGuide！',
#   'tags': ['Java']},
#  {'time': '05_07',
#   'title': 'tauri',
#   'text': 'Build smaller, faster, and more secure desktop applications with a web frontend.',
#   'tags': ['Rust']},
#  {'time': '05_07',
#   'title': 'camel',
#   'text': 'Apache Camel is an open source integration framework that empowers you to quickly and easily integrate various systems consuming or producing data.',
#   'tags': ['Java']},
#  {'time': '05_07',
#   'title': 'adx',
#   'text': 'Experiment in self-authenticating data structures for a federated social network',
#   'tags': ['TypeScript']},
#  {'time': '05_07', 'title': 'Temp', 'text': 'ksjsb', 'tags': []},
#  {'time': '05_07', 'title': 'build-your-own-x', 'text': '', 'tags': []},
#  {'time': '05_08',
#   'title': 'tmagic-editor',
#   'text': '',
#   'tags': ['TypeScript']},
#  {'time': '05_08',
#   'title': 'rustdesk',
#   'text': 'Yet another remote desktop software',
#   'tags': ['Rust']},
#  {'time': '05_08',
#   'title': 'deno',
#   'text': 'A modern runtime for JavaScript and TypeScript.',
#   'tags': ['Rust']},
#  {'time': '05_08',
#   'title': 'easyexcel',
#   'text': '快速、简洁、解决大文件内存溢出的java处理Excel工具',
#   'tags': ['Java']},
#  {'time': '05_08',
#   'title': 'gogs',
#   'text': 'Gogs is a painless self-hosted Git service',
#   'tags': ['Go']},
#  {'time': '05_08',
#   'title': 'vscode',
#   'text': 'Visual Studio Code',
#   'tags': ['TypeScript']},
#  {'time': '05_08', 'title': 'go-by-example', 'text': '', 'tags': ['Go']},
#  {'time': '05_08',
#   'title': 'aptos-core',
#   'text': 'A layer 1 for everyone!',
#   'tags': ['Rust']},
#  {'time': '05_08',
#   'title': 'dive',
#   'text': 'A tool for exploring each layer in a docker image',
#   'tags': ['Go']},
#  {'time': '05_08',
#   'title': 'cloudsploit',
#   'text': 'Cloud Security Posture Management (CSPM)',
#   'tags': ['JavaScript']},
#  {'time': '05_08',
#   'title': 'cs-video-courses',
#   'text': 'List of Computer Science courses with video lectures.',
#   'tags': []},
#  {'time': '05_08',
#   'title': 'foundry',
#   'text': 'Foundry is a blazing fast, portable and modular toolkit for Ethereum application development written in Rust.',
#   'tags': ['Rust']},
#  {'time': '05_08',
#   'title': 'holoiso',
#   'text': 'SteamOS 3 (Holo) archiso configuration',
#   'tags': ['Shell']},
#  {'time': '05_08',
#   'title': 'metersphere',
#   'text': 'MeterSphere 是一站式开源持续测试平台，覆盖测试管理、接口测试、UI 测试和性能测试等。搞测试，就选 MeterSphere！',
#   'tags': ['Java']},
#  {'time': '05_08', 'title': 'clash-tracing', 'text': '', 'tags': ['Go']},
#  {'time': '05_08',
#   'title': 'free-programming-books-zh_CN',
#   'text': '',
#   'tags': []},
#  {'time': '05_08',
#   'title': 'mlops-zoomcamp',
#   'text': 'Free MLOps course from DataTalks.Club',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_08',
#   'title': 'JavaGuide',
#   'text': '「Java学习+面试指南」一份涵盖大部分 Java 程序员所需要掌握的核心知识。准备 Java 面试，首选 JavaGuide！',
#   'tags': ['Java']},
#  {'time': '05_08',
#   'title': 'tauri',
#   'text': 'Build smaller, faster, and more secure desktop applications with a web frontend.',
#   'tags': ['Rust']},
#  {'time': '05_08',
#   'title': 'camel',
#   'text': 'Apache Camel is an open source integration framework that empowers you to quickly and easily integrate various systems consuming or producing data.',
#   'tags': ['Java']},
#  {'time': '05_08',
#   'title': 'adx',
#   'text': 'Experiment in self-authenticating data structures for a federated social network',
#   'tags': ['TypeScript']},
#  {'time': '05_08', 'title': 'Temp', 'text': 'ksjsb', 'tags': []},
#  {'time': '05_08', 'title': 'build-your-own-x', 'text': '', 'tags': []},
#  {'time': '05_08',
#   'title': 'vue-vben-admin',
#   'text': "A modern vue admin. It is based on Vue3, vite and TypeScript. It's fast！",
#   'tags': ['Vue']},
#  {'time': '05_09',
#   'title': 'tauri',
#   'text': 'Build smaller, faster, and more secure desktop applications with a web frontend.',
#   'tags': ['Rust']},
#  {'time': '05_09',
#   'title': 'todomvc-vanillajs-2022',
#   'text': 'Vanilla JS TodoMVC App in 2022',
#   'tags': ['CSS']},
#  {'time': '05_09',
#   'title': 'tmagic-editor',
#   'text': '',
#   'tags': ['TypeScript']},
#  {'time': '05_09',
#   'title': 'zhao',
#   'text': '【编程随想】整理的《太子党关系网络》，专门揭露赵国的权贵',
#   'tags': ['Python']},
#  {'time': '05_09',
#   'title': 'ant-design',
#   'text': 'An enterprise-class UI design language and React UI library',
#   'tags': ['TypeScript']},
#  {'time': '05_09',
#   'title': 'hysteria',
#   'text': 'Hysteria is a feature-packed network utility optimized for networks of poor quality (e.g. satellite connections, congested public Wi-Fi, connecting from China to servers abroad)',
#   'tags': ['Go']},
#  {'time': '05_09',
#   'title': 'gogs',
#   'text': 'Gogs is a painless self-hosted Git service',
#   'tags': ['Go']},
#  {'time': '05_09',
#   'title': 'Babylon.js',
#   'text': 'Babylon.js is a powerful, beautiful, simple, and open game and rendering engine packed into a friendly JavaScript framework.',
#   'tags': ['TypeScript']},
#  {'time': '05_09',
#   'title': 'neuron',
#   'text': 'Open Source Industrial IoT Connectivity Server',
#   'tags': ['C']},
#  {'time': '05_09', 'title': 'go-by-example', 'text': '', 'tags': ['Go']},
#  {'time': '05_09',
#   'title': 'pdf',
#   'text': '编程电子书，电子书，编程书籍，包括C，C#，Docker，Elasticsearch，Git，Hadoop，HeadFirst，Java，Javascript，jvm，Kafka，Linux，Maven，MongoDB，MyBatis，MySQL，Netty，Nginx，Python，RabbitMQ，Redis，Scala，Solr，Spark，Spring，SpringBoot，SpringCloud，TCPIP，Tomcat，Zookeeper，人工智能，大数据类，并发编程，数据库类，数据挖掘，新面试题，架构设计，算法系列，计算机类，设计模式，软件测试，重构优化，等更多分类',
#   'tags': []},
#  {'time': '05_09', 'title': 'clash-tracing', 'text': '', 'tags': ['Go']},
#  {'time': '05_09',
#   'title': 'ddia',
#   'text': '《Designing Data-Intensive Application》DDIA中文翻译',
#   'tags': ['Python']},
#  {'time': '05_09', 'title': 'go-project-example', 'text': '', 'tags': ['Go']},
#  {'time': '05_09',
#   'title': 'Web-Dev-For-Beginners',
#   'text': '24 Lessons, 12 Weeks, Get Started as a Web Developer',
#   'tags': ['JavaScript']},
#  {'time': '05_09',
#   'title': 'rust-course',
#   'text': '“连续六年成为全世界最受喜爱的语言，无 GC 也无需手动内存管理、极高的性能和安全性、过程/OO/函数式编程、优秀的包管理、JS 未来基石" — 工作之余的第二语言来试试 Rust 吧。<<Rust语言圣经>>拥有全面且深入的讲解、生动贴切的示例、德芙般丝滑的内容，甚至还有JS程序员关注的 WASM 和 Deno 等专题。这可能是目前最用心的 Rust 中文学习教程/书籍',
#   'tags': ['Rust']},
#  {'time': '05_09',
#   'title': 'dive',
#   'text': 'A tool for exploring each layer in a docker image',
#   'tags': ['Go']},
#  {'time': '05_09',
#   'title': 'cs-video-courses',
#   'text': 'List of Computer Science courses with video lectures.',
#   'tags': []},
#  {'time': '05_09',
#   'title': 'lossless-cut',
#   'text': 'The swiss army knife of lossless video/audio editing',
#   'tags': ['JavaScript']},
#  {'time': '05_09',
#   'title': 'lowcode-engine',
#   'text': 'An enterprise-class low-code technology stack with scale-out design / 一套面向扩展设计的企业级低代码技术体系',
#   'tags': ['TypeScript']},
#  {'time': '05_09',
#   'title': 'universal-android-debloater',
#   'text': 'Cross-platform GUI written in Rust using ADB to debloat non-rooted android devices. Improve your privacy, the security and battery life of your device.',
#   'tags': ['Rust']},
#  {'time': '05_09',
#   'title': 'metersphere',
#   'text': 'MeterSphere 是一站式开源持续测试平台，覆盖测试管理、接口测试、UI 测试和性能测试等。搞测试，就选 MeterSphere！',
#   'tags': ['Java']},
#  {'time': '05_09',
#   'title': 'FUCK-GFW',
#   'text': '记录各个包管理器使用代理的方法, 因为GFW已经浪费了已经数不清的时间, FUCK GFW',
#   'tags': []},
#  {'time': '05_09',
#   'title': 'GitHubDaily',
#   'text': '坚持分享 GitHub 上高质量、有趣实用的开源技术教程、开发者工具、编程网站、技术资讯。A list cool, interesting projects of GitHub.',
#   'tags': []},
#  {'time': '05_10',
#   'title': 'Web-Dev-For-Beginners',
#   'text': '24 Lessons, 12 Weeks, Get Started as a Web Developer',
#   'tags': ['JavaScript']},
#  {'time': '05_10',
#   'title': 'tauri',
#   'text': 'Build smaller, faster, and more secure desktop applications with a web frontend.',
#   'tags': ['Rust']},
#  {'time': '05_10',
#   'title': 'Grasscutter',
#   'text': 'A server software reimplementation for a certain anime game.',
#   'tags': ['Java']},
#  {'time': '05_10', 'title': 'alist', 'text': '', 'tags': ['Go']},
#  {'time': '05_10',
#   'title': 'yt-dlp',
#   'text': 'A youtube-dl fork with additional features and fixes',
#   'tags': ['Python']},
#  {'time': '05_10', 'title': 'ML-Course-Notes', 'text': '', 'tags': []},
#  {'time': '05_10', 'title': 'go-project-example', 'text': '', 'tags': ['Go']},
#  {'time': '05_10',
#   'title': 'virtual-bookshelf',
#   'text': 'A simple bookshelf made in CSS, HTML and vanilla JS.',
#   'tags': ['CSS']},
#  {'time': '05_10',
#   'title': 'universal-android-debloater',
#   'text': 'Cross-platform GUI written in Rust using ADB to debloat non-rooted android devices. Improve your privacy, the security and battery life of your device.',
#   'tags': ['Rust']},
#  {'time': '05_10',
#   'title': 'mlops-zoomcamp',
#   'text': 'Free MLOps course from DataTalks.Club',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_10',
#   'title': 'data-engineering-zoomcamp',
#   'text': 'Free Data Engineering course! ',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_10',
#   'title': 'termux-packages',
#   'text': 'A build system and primary set of packages for Termux.',
#   'tags': ['Shell']},
#  {'time': '05_10',
#   'title': 'tailwindcss',
#   'text': 'A utility-first CSS framework for rapid UI development.',
#   'tags': ['JavaScript']},
#  {'time': '05_10',
#   'title': 'Real-ESRGAN',
#   'text': 'Real-ESRGAN aims at developing Practical Algorithms for General Image/Video Restoration.',
#   'tags': ['Python']},
#  {'time': '05_10',
#   'title': 'lossless-cut',
#   'text': 'The swiss army knife of lossless video/audio editing',
#   'tags': ['JavaScript']},
#  {'time': '05_10',
#   'title': 'calculator',
#   'text': 'Windows Calculator: A simple yet powerful calculator that ships with Windows',
#   'tags': ['C++']},
#  {'time': '05_10', 'title': 'core', 'text': '', 'tags': ['Python']},
#  {'time': '05_10',
#   'title': 'NvChad',
#   'text': 'An attempt to make neovim cli functional like an IDE while being very beautiful, blazing fast startuptime ~ 20ms to 70ms',
#   'tags': ['Lua']},
#  {'time': '05_10',
#   'title': 'tmagic-editor',
#   'text': '',
#   'tags': ['TypeScript']},
#  {'time': '05_10',
#   'title': 'kratos',
#   'text': 'Your ultimate Go microservices framework for the cloud-native era.',
#   'tags': ['Go']},
#  {'time': '05_10',
#   'title': 'Tasmota',
#   'text': 'Alternative firmware for ESP8266 with easy configuration using webUI, OTA updates, automation using timers or rules, expandability and entirely local control over MQTT, HTTP, Serial or KNX. Full documentation at',
#   'tags': ['C']},
#  {'time': '05_10',
#   'title': 'logseq',
#   'text': 'A privacy-first, open-source platform for knowledge management and collaboration. Desktop app download link:',
#   'tags': ['Clojure']},
#  {'time': '05_10',
#   'title': 'dolphin',
#   'text': 'Dolphin is a GameCube / Wii emulator, allowing you to play games for these two platforms on PC with improvements.',
#   'tags': ['C++']},
#  {'time': '05_10',
#   'title': 'gogs',
#   'text': 'Gogs is a painless self-hosted Git service',
#   'tags': ['Go']},
#  {'time': '05_11', 'title': 'fastjson2', 'text': '', 'tags': ['Java']},
#  {'time': '05_11',
#   'title': 'nuclei-templates',
#   'text': 'Community curated list of templates for the nuclei engine to find security vulnerabilities.',
#   'tags': ['Python']},
#  {'time': '05_11', 'title': 'ML-Course-Notes', 'text': '', 'tags': []},
#  {'time': '05_11',
#   'title': 'mlops-zoomcamp',
#   'text': 'Free MLOps course from DataTalks.Club',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_11',
#   'title': 'NBMiner',
#   'text': 'GPU Miner for ETH, RVN, BEAM, CFX, ZIL, AE, ERGO',
#   'tags': []},
#  {'time': '05_11',
#   'title': 'Web-Dev-For-Beginners',
#   'text': '24 Lessons, 12 Weeks, Get Started as a Web Developer',
#   'tags': ['JavaScript']},
#  {'time': '05_11',
#   'title': 'tesseract.js',
#   'text': 'Pure Javascript OCR for more than 100 Languages',
#   'tags': ['JavaScript']},
#  {'time': '05_11',
#   'title': 'awesome-compose',
#   'text': 'Awesome Docker Compose samples',
#   'tags': ['HTML']},
#  {'time': '05_11',
#   'title': 'DeepLearning-MuLi-Notes',
#   'text': 'Notes about courses Dive into Deep Learning by Mu Li',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_11',
#   'title': 'weron',
#   'text': 'Overlay networks based on WebRTC.',
#   'tags': ['Go']},
#  {'time': '05_11',
#   'title': 'ddia',
#   'text': '《Designing Data-Intensive Application》DDIA中文翻译',
#   'tags': ['Python']},
#  {'time': '05_11',
#   'title': 'tauri',
#   'text': 'Build smaller, faster, and more secure desktop applications with a web frontend.',
#   'tags': ['Rust']},
#  {'time': '05_11',
#   'title': 'nginxconfig.io',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_11',
#   'title': 'kratos',
#   'text': 'Your ultimate Go microservices framework for the cloud-native era.',
#   'tags': ['Go']},
#  {'time': '05_11',
#   'title': 'AspNetCore-Developer-Roadmap',
#   'text': 'Roadmap to becoming an ASP.NET Core developer in 2022',
#   'tags': []},
#  {'time': '05_11',
#   'title': 'mlbookcamp-code',
#   'text': 'The code from the Machine Learning Bookcamp book and a free course based on the book',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_11',
#   'title': '90DaysOfDevOps',
#   'text': 'This repository is my documenting repository for learning the world of DevOps. I started this journey on the 1st January 2022 and I plan to run to March 31st for a complete 90-day romp on spending an hour a day including weekends to get a foundational knowledge across a lot of different areas that make up DevOps. ',
#   'tags': ['Shell']},
#  {'time': '05_11',
#   'title': 'booking-microservices-sample',
#   'text': 'Booking Microservices is a Sample application for booking ticket. This application based on different software architecture and technologies like .Net Core, CQRS, DDD, Vertical Slice Architecture, Docker, kubernetes, tye, masstransit, RabbitMQ, Grpc, yarp reverse proxy, Identity Server, Redis, SqlServer, Entity Framework Core, Event Sourcing and…',
#   'tags': ['C#']},
#  {'time': '05_11',
#   'title': 'applied-methods-phd',
#   'text': 'Repo for Yale Applied Empirical Methods PHD Course',
#   'tags': ['TeX']},
#  {'time': '05_11',
#   'title': 'django-orm-cheatsheet',
#   'text': 'A cheatsheet for the Django ORM',
#   'tags': []},
#  {'time': '05_11',
#   'title': 'gogs',
#   'text': 'Gogs is a painless self-hosted Git service',
#   'tags': ['Go']},
#  {'time': '05_11',
#   'title': 'googletest',
#   'text': 'GoogleTest - Google Testing and Mocking Framework',
#   'tags': ['C++']},
#  {'time': '05_11',
#   'title': 'kubesphere',
#   'text': 'The container platform tailored for Kubernetes multi-cloud, datacenter, and edge management ⎈',
#   'tags': ['Go']},
#  {'time': '05_11',
#   'title': 'Babylon.js',
#   'text': 'Babylon.js is a powerful, beautiful, simple, and open game and rendering engine packed into a friendly JavaScript framework.',
#   'tags': ['TypeScript']},
#  {'time': '05_13',
#   'title': 'googletest',
#   'text': 'GoogleTest - Google Testing and Mocking Framework',
#   'tags': ['C++']},
#  {'time': '05_13',
#   'title': 'nuclei-templates',
#   'text': 'Community curated list of templates for the nuclei engine to find security vulnerabilities.',
#   'tags': ['Python']},
#  {'time': '05_13',
#   'title': 'nginxconfig.io',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_13',
#   'title': 'flutter',
#   'text': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond',
#   'tags': ['Dart']},
#  {'time': '05_13',
#   'title': 'PaddleOCR',
#   'text': 'Awesome multilingual OCR toolkits based on PaddlePaddle (practical ultra lightweight OCR system, support 80+ languages recognition, provide data annotation and synthesis tools, support training and deployment among server, mobile, embedded and IoT devices)',
#   'tags': ['Python']},
#  {'time': '05_13',
#   'title': 'pinball',
#   'text': 'Google I/O 2022 Pinball game built with Flutter and Firebase',
#   'tags': ['Dart']},
#  {'time': '05_13',
#   'title': 'go-pprof-practice',
#   'text': 'go pprof practice.',
#   'tags': ['Go']},
#  {'time': '05_13',
#   'title': 'supabase',
#   'text': 'The open source Firebase alternative. Follow to stay updated about our public Beta.',
#   'tags': ['TypeScript']},
#  {'time': '05_13',
#   'title': 'frontend-challenges',
#   'text': 'A public list of open-source challenges from companies around the world',
#   'tags': []},
#  {'time': '05_13',
#   'title': 'samples',
#   'text': 'A collection of Flutter examples and demos',
#   'tags': ['Dart']},
#  {'time': '05_13', 'title': 'fastjson2', 'text': '', 'tags': ['Java']},
#  {'time': '05_13',
#   'title': 'app-ideas',
#   'text': 'A Collection of application ideas which can be used to improve your coding skills.',
#   'tags': []},
#  {'time': '05_13',
#   'title': 'bubbletea',
#   'text': 'A powerful little TUI framework',
#   'tags': ['Go']},
#  {'time': '05_13', 'title': 'transformers', 'text': '', 'tags': ['Python']},
#  {'time': '05_13',
#   'title': 'data-engineering-with-databricks',
#   'text': '',
#   'tags': ['Python']},
#  {'time': '05_13',
#   'title': 'reader',
#   'text': '阅读3服务器版，桌面端。后端 Kotlin + Spring Boot + Vert.x + Coroutine ；前端 Vue.js + Element',
#   'tags': ['Kotlin']},
#  {'time': '05_13',
#   'title': 'azure-rest-api-specs',
#   'text': 'The source for REST API specifications for Microsoft Azure.',
#   'tags': ['TypeScript']},
#  {'time': '05_13',
#   'title': 'core',
#   'text': 'GO implementation of the Terra Protocol ',
#   'tags': ['JavaScript']},
#  {'time': '05_13',
#   'title': 'salt',
#   'text': 'Software to automate the management and configuration of any infrastructure or application at scale. Get access to the Salt software package repository here: ',
#   'tags': ['Python']},
#  {'time': '05_13',
#   'title': 'cs-self-learning',
#   'text': '计算机自学指南',
#   'tags': ['HTML']},
#  {'time': '05_13',
#   'title': 'virtual-environments',
#   'text': 'GitHub Actions virtual environments',
#   'tags': ['PowerShell']},
#  {'time': '05_13',
#   'title': 'junior-recruit-scheduler',
#   'text': '주니어 개발자 채용 정보',
#   'tags': ['JavaScript']},
#  {'time': '05_13',
#   'title': 'aspnetcore',
#   'text': 'ASP.NET Core is a cross-platform .NET framework for building modern cloud-based web applications on Windows, Mac, or Linux.',
#   'tags': ['C#']},
#  {'time': '05_13',
#   'title': 'Charts',
#   'text': 'Beautiful charts for iOS/tvOS/OSX! The Apple side of the crossplatform MPAndroidChart.',
#   'tags': ['Swift']},
#  {'time': '05_14',
#   'title': 'googletest',
#   'text': 'GoogleTest - Google Testing and Mocking Framework',
#   'tags': ['C++']},
#  {'time': '05_14',
#   'title': 'nuclei-templates',
#   'text': 'Community curated list of templates for the nuclei engine to find security vulnerabilities.',
#   'tags': ['Python']},
#  {'time': '05_14',
#   'title': 'nginxconfig.io',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_14',
#   'title': 'flutter',
#   'text': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond',
#   'tags': ['Dart']},
#  {'time': '05_14',
#   'title': 'PaddleOCR',
#   'text': 'Awesome multilingual OCR toolkits based on PaddlePaddle (practical ultra lightweight OCR system, support 80+ languages recognition, provide data annotation and synthesis tools, support training and deployment among server, mobile, embedded and IoT devices)',
#   'tags': ['Python']},
#  {'time': '05_14',
#   'title': 'pinball',
#   'text': 'Google I/O 2022 Pinball game built with Flutter and Firebase',
#   'tags': ['Dart']},
#  {'time': '05_14',
#   'title': 'go-pprof-practice',
#   'text': 'go pprof practice.',
#   'tags': ['Go']},
#  {'time': '05_14',
#   'title': 'supabase',
#   'text': 'The open source Firebase alternative. Follow to stay updated about our public Beta.',
#   'tags': ['TypeScript']},
#  {'time': '05_14',
#   'title': 'frontend-challenges',
#   'text': 'A public list of open-source challenges from companies around the world',
#   'tags': []},
#  {'time': '05_14',
#   'title': 'samples',
#   'text': 'A collection of Flutter examples and demos',
#   'tags': ['Dart']},
#  {'time': '05_14', 'title': 'fastjson2', 'text': '', 'tags': ['Java']},
#  {'time': '05_14',
#   'title': 'app-ideas',
#   'text': 'A Collection of application ideas which can be used to improve your coding skills.',
#   'tags': []},
#  {'time': '05_14',
#   'title': 'bubbletea',
#   'text': 'A powerful little TUI framework',
#   'tags': ['Go']},
#  {'time': '05_14', 'title': 'transformers', 'text': '', 'tags': ['Python']},
#  {'time': '05_14',
#   'title': 'data-engineering-with-databricks',
#   'text': '',
#   'tags': ['Python']},
#  {'time': '05_14',
#   'title': 'reader',
#   'text': '阅读3服务器版，桌面端。后端 Kotlin + Spring Boot + Vert.x + Coroutine ；前端 Vue.js + Element',
#   'tags': ['Kotlin']},
#  {'time': '05_14',
#   'title': 'azure-rest-api-specs',
#   'text': 'The source for REST API specifications for Microsoft Azure.',
#   'tags': ['TypeScript']},
#  {'time': '05_14',
#   'title': 'core',
#   'text': 'GO implementation of the Terra Protocol ',
#   'tags': ['JavaScript']},
#  {'time': '05_14',
#   'title': 'salt',
#   'text': 'Software to automate the management and configuration of any infrastructure or application at scale. Get access to the Salt software package repository here: ',
#   'tags': ['Python']},
#  {'time': '05_14',
#   'title': 'cs-self-learning',
#   'text': '计算机自学指南',
#   'tags': ['HTML']},
#  {'time': '05_14',
#   'title': 'virtual-environments',
#   'text': 'GitHub Actions virtual environments',
#   'tags': ['PowerShell']},
#  {'time': '05_14',
#   'title': 'junior-recruit-scheduler',
#   'text': '주니어 개발자 채용 정보',
#   'tags': ['JavaScript']},
#  {'time': '05_14',
#   'title': 'aspnetcore',
#   'text': 'ASP.NET Core is a cross-platform .NET framework for building modern cloud-based web applications on Windows, Mac, or Linux.',
#   'tags': ['C#']},
#  {'time': '05_14',
#   'title': 'Charts',
#   'text': 'Beautiful charts for iOS/tvOS/OSX! The Apple side of the crossplatform MPAndroidChart.',
#   'tags': ['Swift']},
#  {'time': '05_15',
#   'title': 'googletest',
#   'text': 'GoogleTest - Google Testing and Mocking Framework',
#   'tags': ['C++']},
#  {'time': '05_15',
#   'title': 'nuclei-templates',
#   'text': 'Community curated list of templates for the nuclei engine to find security vulnerabilities.',
#   'tags': ['Python']},
#  {'time': '05_15',
#   'title': 'nginxconfig.io',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_15',
#   'title': 'flutter',
#   'text': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond',
#   'tags': ['Dart']},
#  {'time': '05_15',
#   'title': 'PaddleOCR',
#   'text': 'Awesome multilingual OCR toolkits based on PaddlePaddle (practical ultra lightweight OCR system, support 80+ languages recognition, provide data annotation and synthesis tools, support training and deployment among server, mobile, embedded and IoT devices)',
#   'tags': ['Python']},
#  {'time': '05_15',
#   'title': 'pinball',
#   'text': 'Google I/O 2022 Pinball game built with Flutter and Firebase',
#   'tags': ['Dart']},
#  {'time': '05_15',
#   'title': 'go-pprof-practice',
#   'text': 'go pprof practice.',
#   'tags': ['Go']},
#  {'time': '05_15',
#   'title': 'supabase',
#   'text': 'The open source Firebase alternative. Follow to stay updated about our public Beta.',
#   'tags': ['TypeScript']},
#  {'time': '05_15',
#   'title': 'frontend-challenges',
#   'text': 'A public list of open-source challenges from companies around the world',
#   'tags': []},
#  {'time': '05_15',
#   'title': 'samples',
#   'text': 'A collection of Flutter examples and demos',
#   'tags': ['Dart']},
#  {'time': '05_15', 'title': 'fastjson2', 'text': '', 'tags': ['Java']},
#  {'time': '05_15',
#   'title': 'app-ideas',
#   'text': 'A Collection of application ideas which can be used to improve your coding skills.',
#   'tags': []},
#  {'time': '05_15',
#   'title': 'bubbletea',
#   'text': 'A powerful little TUI framework',
#   'tags': ['Go']},
#  {'time': '05_15', 'title': 'transformers', 'text': '', 'tags': ['Python']},
#  {'time': '05_15',
#   'title': 'data-engineering-with-databricks',
#   'text': '',
#   'tags': ['Python']},
#  {'time': '05_15',
#   'title': 'reader',
#   'text': '阅读3服务器版，桌面端。后端 Kotlin + Spring Boot + Vert.x + Coroutine ；前端 Vue.js + Element。',
#   'tags': ['Kotlin']},
#  {'time': '05_15',
#   'title': 'azure-rest-api-specs',
#   'text': 'The source for REST API specifications for Microsoft Azure.',
#   'tags': ['TypeScript']},
#  {'time': '05_15',
#   'title': 'core',
#   'text': 'GO implementation of the Terra Protocol ',
#   'tags': ['JavaScript']},
#  {'time': '05_15',
#   'title': 'salt',
#   'text': 'Software to automate the management and configuration of any infrastructure or application at scale. Get access to the Salt software package repository here: ',
#   'tags': ['Python']},
#  {'time': '05_15',
#   'title': 'cs-self-learning',
#   'text': '计算机自学指南',
#   'tags': ['HTML']},
#  {'time': '05_15',
#   'title': 'virtual-environments',
#   'text': 'GitHub Actions virtual environments',
#   'tags': ['PowerShell']},
#  {'time': '05_15',
#   'title': 'junior-recruit-scheduler',
#   'text': '주니어 개발자 채용 정보',
#   'tags': ['JavaScript']},
#  {'time': '05_15',
#   'title': 'aspnetcore',
#   'text': 'ASP.NET Core is a cross-platform .NET framework for building modern cloud-based web applications on Windows, Mac, or Linux.',
#   'tags': ['C#']},
#  {'time': '05_15',
#   'title': 'Charts',
#   'text': 'Beautiful charts for iOS/tvOS/OSX! The Apple side of the crossplatform MPAndroidChart.',
#   'tags': ['Swift']},
#  {'time': '05_16',
#   'title': 'flutter',
#   'text': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond',
#   'tags': ['Dart']},
#  {'time': '05_16',
#   'title': 'aptos-core',
#   'text': 'A layer 1 for everyone!',
#   'tags': ['Rust']},
#  {'time': '05_16',
#   'title': 'You-Dont-Know-JS',
#   'text': 'A book series on JavaScript.',
#   'tags': []},
#  {'time': '05_16',
#   'title': 'nowinandroid',
#   'text': 'A fully functional Android app built entirely with Kotlin and Jetpack Compose',
#   'tags': ['Kotlin']},
#  {'time': '05_16',
#   'title': 'nuclei-templates',
#   'text': 'Community curated list of templates for the nuclei engine to find security vulnerabilities.',
#   'tags': ['Python']},
#  {'time': '05_16',
#   'title': 'googletest',
#   'text': 'GoogleTest - Google Testing and Mocking Framework',
#   'tags': ['C++']},
#  {'time': '05_16', 'title': 'LiveTerm', 'text': '', 'tags': ['TypeScript']},
#  {'time': '05_16', 'title': 'xdg-ninja', 'text': '', 'tags': ['Shell']},
#  {'time': '05_16',
#   'title': '30-Days-Of-JavaScript',
#   'text': '30 days of JavaScript programming challenge is a step-by-step guide to learn JavaScript programming language in 30 days. This challenge may take more than 100 days, please just follow your own pace. ',
#   'tags': ['JavaScript']},
#  {'time': '05_16',
#   'title': 'lapce',
#   'text': 'Lightning-fast and Powerful Code Editor written in Rust',
#   'tags': ['Rust']},
#  {'time': '05_16',
#   'title': 'nannyml',
#   'text': 'Detecting silent model failure. NannyML estimates performance with an algorithm called Confidence-based Performance estimation (CBPE), developed by core contributors. It is the only open-source algorithm capable of fully capturing the impact of data drift on performance.',
#   'tags': ['Python']},
#  {'time': '05_16',
#   'title': 'solmate',
#   'text': 'Modern, opinionated, and gas optimized building blocks for smart contract development.',
#   'tags': ['Solidity']},
#  {'time': '05_16',
#   'title': 'app-ideas',
#   'text': 'A Collection of application ideas which can be used to improve your coding skills.',
#   'tags': []},
#  {'time': '05_16',
#   'title': 'Geeker-Admin',
#   'text': 'Geeker Admin，基于 Vue3.2、TypeScript、Vite2、Pinia、Element-Plus 开发的一套后台管理框架。',
#   'tags': ['Vue']},
#  {'time': '05_16',
#   'title': 'clean-code-javascript',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_16',
#   'title': 'supabase',
#   'text': 'The open source Firebase alternative. Follow to stay updated about our public Beta.',
#   'tags': ['TypeScript']},
#  {'time': '05_16', 'title': 'HEU_KMS_Activator', 'text': '', 'tags': []},
#  {'time': '05_16',
#   'title': 'dokku',
#   'text': 'A docker-powered PaaS that helps you build and manage the lifecycle of applications',
#   'tags': ['Shell']},
#  {'time': '05_16',
#   'title': 'DSA-Bootcamp-Java',
#   'text': 'This repository consists of the code samples, assignments, and notes for the Java Data Structures & Algorithms bootcamp of Community Classroom.',
#   'tags': ['Java']},
#  {'time': '05_16',
#   'title': 'tachiyomi',
#   'text': 'Free and open source manga reader for Android.',
#   'tags': ['Kotlin']},
#  {'time': '05_16',
#   'title': 'javascript-algorithms',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_16',
#   'title': 'clash_for_windows_pkg',
#   'text': 'A Windows/macOS GUI based on Clash',
#   'tags': []},
#  {'time': '05_16', 'title': 'awesome', 'text': '', 'tags': []},
#  {'time': '05_16',
#   'title': 'PathOfBuilding',
#   'text': 'Offline build planner for Path of Exile.',
#   'tags': ['Lua']},
#  {'time': '05_17',
#   'title': 'nowinandroid',
#   'text': 'A fully functional Android app built entirely with Kotlin and Jetpack Compose',
#   'tags': ['Kotlin']},
#  {'time': '05_17',
#   'title': 'flutter',
#   'text': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond',
#   'tags': ['Dart']},
#  {'time': '05_17',
#   'title': 'xdg-ninja',
#   'text': 'A shell script which checks your $HOME for unwanted files and directories.',
#   'tags': ['Shell']},
#  {'time': '05_17',
#   'title': 'jellyfin',
#   'text': 'The Free Software Media System',
#   'tags': ['C#']},
#  {'time': '05_17',
#   'title': 'run',
#   'text': '润学全球官方指定GITHUB，整理润学宗旨、纲领、理论和各类润之实例；解决为什么润，润去哪里，怎么润三大问题； 并成为新中国人的核心宗教，核心信念。',
#   'tags': []},
#  {'time': '05_17', 'title': 'awesome', 'text': '', 'tags': []},
#  {'time': '05_17',
#   'title': 'aptos-core',
#   'text': 'A layer 1 for everyone!',
#   'tags': ['Rust']},
#  {'time': '05_17',
#   'title': 'Flipper-IRDB',
#   'text': 'A collective of different IRs for the Flipper',
#   'tags': []},
#  {'time': '05_17',
#   'title': 'yt-dlp',
#   'text': 'A youtube-dl fork with additional features and fixes',
#   'tags': ['Python']},
#  {'time': '05_17',
#   'title': 'Python-100-Days',
#   'text': 'Python - 100天从新手到大师',
#   'tags': ['Python']},
#  {'time': '05_17',
#   'title': 'cs-video-courses',
#   'text': 'List of Computer Science courses with video lectures.',
#   'tags': []},
#  {'time': '05_17',
#   'title': 'gofound',
#   'text': 'GoFound GoLang Full text search go语言全文检索引擎 基于平衡二叉树+正排索引、倒排索引实现 可支持亿级数据，毫秒级查询。 使用简单，使用http接口，任何系统都可以使用。',
#   'tags': ['Go']},
#  {'time': '05_17',
#   'title': 'CyberController',
#   'text': 'CyberController',
#   'tags': ['Java']},
#  {'time': '05_17',
#   'title': 'Neovim-from-scratch',
#   'text': 'A Neovim config designed from scratch to be understandable',
#   'tags': ['Lua']},
#  {'time': '05_17', 'title': 'rustlings', 'text': '', 'tags': ['Rust']},
#  {'time': '05_17',
#   'title': 'clean-code-javascript',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_17',
#   'title': 'clash',
#   'text': 'A rule-based tunnel in Go.',
#   'tags': ['Go']},
#  {'time': '05_17', 'title': 'LiveTerm', 'text': '', 'tags': ['TypeScript']},
#  {'time': '05_17', 'title': 'Shipwright', 'text': '', 'tags': ['C']},
#  {'time': '05_17',
#   'title': 'authelia',
#   'text': 'The Single Sign-On Multi-Factor portal for web apps',
#   'tags': ['Go']},
#  {'time': '05_17',
#   'title': 'docs',
#   'text': 'The open-source repo for docs.github.com',
#   'tags': ['JavaScript']},
#  {'time': '05_17',
#   'title': 'Paper',
#   'text': 'High performance Spigot fork that aims to fix gameplay and mechanics inconsistencies',
#   'tags': ['Java']},
#  {'time': '05_17',
#   'title': 'imgui',
#   'text': 'Dear ImGui: Bloat-free Graphical User interface for C++ with minimal dependencies',
#   'tags': ['C++']},
#  {'time': '05_17',
#   'title': 'go-clean-template',
#   'text': 'Clean Architecture template for Golang services',
#   'tags': ['Go']},
#  {'time': '05_18',
#   'title': 'mlops-zoomcamp',
#   'text': 'Free MLOps course from DataTalks.Club',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_18', 'title': 'sql-generator', 'text': '', 'tags': ['Vue']},
#  {'time': '05_18',
#   'title': 'Geeker-Admin',
#   'text': 'Geeker Admin，基于 Vue3.2、TypeScript、Vite2、Pinia、Element-Plus 开发的一套后台管理框架。',
#   'tags': ['Vue']},
#  {'time': '05_18',
#   'title': 'activate-linux',
#   'text': 'The "Activate Windows" watermark ported to Linux',
#   'tags': ['C']},
#  {'time': '05_18',
#   'title': 'aptos-core',
#   'text': 'A layer 1 for everyone!',
#   'tags': ['Rust']},
#  {'time': '05_18',
#   'title': 'nowinandroid',
#   'text': 'A fully functional Android app built entirely with Kotlin and Jetpack Compose',
#   'tags': ['Kotlin']},
#  {'time': '05_18',
#   'title': 'beautify-github-profile',
#   'text': 'This repository helps you to have a more beautiful and attractive github profile, and you can access a set of tools and guides for beautifying your github profile.',
#   'tags': []},
#  {'time': '05_18', 'title': 'HEU_KMS_Activator', 'text': '', 'tags': []},
#  {'time': '05_18',
#   'title': 'linux-insides',
#   'text': 'A little bit about a linux kernel',
#   'tags': ['Python']},
#  {'time': '05_18',
#   'title': 'Aman-Barnwal-Leetcode-Solutions',
#   'text': 'This repo contains my Leetcode Solutions question-wise !',
#   'tags': ['C++']},
#  {'time': '05_18',
#   'title': 'python-buffered-reader-exploit',
#   'text': '',
#   'tags': ['Python']},
#  {'time': '05_18', 'title': 'LiveTerm', 'text': '', 'tags': ['TypeScript']},
#  {'time': '05_18',
#   'title': 'cs-video-courses',
#   'text': 'List of Computer Science courses with video lectures.',
#   'tags': []},
#  {'time': '05_18',
#   'title': 'id-server',
#   'text': 'An OAuth2 Authorization Server,Based on Spring Authorization Server',
#   'tags': ['JavaScript']},
#  {'time': '05_18',
#   'title': 'gofound',
#   'text': 'GoFound GoLang Full text search go语言全文检索引擎 基于平衡二叉树+正排索引、倒排索引实现 可支持亿级数据，毫秒级查询。 使用简单，使用http接口，任何系统都可以使用。',
#   'tags': ['Go']},
#  {'time': '05_18',
#   'title': 'PaddleNLP',
#   'text': 'Easy-to-use and powerful NLP library with awesome model zoo, supporting wide-range of NLP tasks from research to industrial applications. Including Neural Search, Question Answering, Information Extraction and Sentiment Analysis end-to-end system.',
#   'tags': ['Python']},
#  {'time': '05_18',
#   'title': 'CodeEdit',
#   'text': 'CodeEdit App for macOS – Elevate your code editing experience. Open source, free forever.',
#   'tags': ['Swift']},
#  {'time': '05_18',
#   'title': 'CyberController',
#   'text': 'CyberController',
#   'tags': ['Java']},
#  {'time': '05_18',
#   'title': 'lapce',
#   'text': 'Lightning-fast and Powerful Code Editor written in Rust',
#   'tags': ['Rust']},
#  {'time': '05_18',
#   'title': 'ailia-models',
#   'text': 'The collection of pre-trained, state-of-the-art AI models for ailia SDK',
#   'tags': ['Python']},
#  {'time': '05_18',
#   'title': 'AppFlowy',
#   'text': 'AppFlowy is an open-source alternative to Notion. You are in charge of your data and customizations. Built with Flutter and Rust.',
#   'tags': ['Rust']},
#  {'time': '05_18',
#   'title': 'vosk-api',
#   'text': 'Offline speech recognition API for Android, iOS, Raspberry Pi and servers with Python, Java, C# and Node',
#   'tags': ['C++']},
#  {'time': '05_18',
#   'title': 'dokku',
#   'text': 'A docker-powered PaaS that helps you build and manage the lifecycle of applications',
#   'tags': ['Shell']},
#  {'time': '05_18',
#   'title': 'You-Dont-Know-JS',
#   'text': 'A book series on JavaScript.',
#   'tags': []},
#  {'time': '05_19', 'title': 'sql-generator', 'text': '', 'tags': ['Vue']},
#  {'time': '05_19',
#   'title': 'CodeEdit',
#   'text': 'CodeEdit App for macOS – Elevate your code editing experience. Open source, free forever.',
#   'tags': ['Swift']},
#  {'time': '05_19',
#   'title': 'mitmproxy',
#   'text': 'An interactive TLS-capable intercepting HTTP proxy for penetration testers and software developers.',
#   'tags': ['Python']},
#  {'time': '05_19',
#   'title': 'run',
#   'text': '润学全球官方指定GITHUB，整理润学宗旨、纲领、理论和各类润之实例；解决为什么润，润去哪里，怎么润三大问题； 并成为新中国人的核心宗教，核心信念。',
#   'tags': []},
#  {'time': '05_19',
#   'title': 'tetragon',
#   'text': 'eBPF-based Security Observability and Runtime Enforcement',
#   'tags': ['C']},
#  {'time': '05_19',
#   'title': 'aptos-core',
#   'text': 'A layer 1 for everyone!',
#   'tags': ['Rust']},
#  {'time': '05_19',
#   'title': 'activate-linux',
#   'text': 'The "Activate Windows" watermark ported to Linux',
#   'tags': ['C']},
#  {'time': '05_19',
#   'title': 'kitex-examples',
#   'text': 'Examples for Kitex.',
#   'tags': ['Go']},
#  {'time': '05_19',
#   'title': 'PaddleNLP',
#   'text': 'Easy-to-use and powerful NLP library with Awesome model zoo, supporting wide-range of NLP tasks from research to industrial applications, including Neural Search, Question Answering, Information Extraction and Sentiment Analysis end-to-end system.',
#   'tags': ['Python']},
#  {'time': '05_19',
#   'title': 'beautify-github-profile',
#   'text': 'This repository helps you to have a more beautiful and attractive github profile, and you can access a complete set of tools and guides for beautifying your github profile.',
#   'tags': []},
#  {'time': '05_19',
#   'title': 'Python-100-Days',
#   'text': 'Python - 100天从新手到大师',
#   'tags': ['Python']},
#  {'time': '05_19',
#   'title': 'go-cqhttp',
#   'text': 'cqhttp的golang实现，轻量、原生跨平台.',
#   'tags': ['Go']},
#  {'time': '05_19',
#   'title': 'en.javascript.info',
#   'text': 'Modern JavaScript Tutorial ',
#   'tags': ['HTML']},
#  {'time': '05_19',
#   'title': 'web3.js',
#   'text': 'Ethereum JavaScript API',
#   'tags': ['JavaScript']},
#  {'time': '05_19',
#   'title': 'Awesome-RCE-techniques',
#   'text': 'Awesome list of techniques to achieve Remote Code Execution on various apps! ',
#   'tags': ['Dockerfile']},
#  {'time': '05_19', 'title': 'kbd-audio', 'text': '', 'tags': ['C++']},
#  {'time': '05_19',
#   'title': 'opencti',
#   'text': 'Open Cyber Threat Intelligence Platform',
#   'tags': ['JavaScript']},
#  {'time': '05_19',
#   'title': 'go-clean-template',
#   'text': 'Clean Architecture template for Golang services',
#   'tags': ['Go']},
#  {'time': '05_19',
#   'title': 'You-Dont-Know-JS',
#   'text': 'A book series on JavaScript.',
#   'tags': []},
#  {'time': '05_19',
#   'title': 'prefect',
#   'text': 'The easiest way to automate your data',
#   'tags': ['Python']},
#  {'time': '05_19',
#   'title': 'ionic-framework',
#   'text': 'A powerful cross-platform UI toolkit for building native-quality iOS, Android, and Progressive Web Apps with HTML, CSS, and JavaScript.',
#   'tags': ['TypeScript']},
#  {'time': '05_19',
#   'title': 'gin',
#   'text': 'Gin is a HTTP web framework written in Go (Golang). It features a Martini-like API with much better performance -- up to 40 times faster. If you need smashing performance, get yourself some Gin.',
#   'tags': ['Go']},
#  {'time': '05_19',
#   'title': 'malware_showcase',
#   'text': 'Understand the nature of malicious software with practical examples in Python.',
#   'tags': ['Python']},
#  {'time': '05_19',
#   'title': 'mlops-zoomcamp',
#   'text': 'Free MLOps course from DataTalks.Club',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_20',
#   'title': 'CodeEdit',
#   'text': 'CodeEdit App for macOS – Elevate your code editing experience. Open source, free forever.',
#   'tags': ['Swift']},
#  {'time': '05_20',
#   'title': 'zhenxun_bot',
#   'text': '基于 Nonebot2 和 go-cqhttp 开发，以 postgresql 作为数据库，非常可爱的绪山真寻bot',
#   'tags': []},
#  {'time': '05_20',
#   'title': 'gofound',
#   'text': 'GoFound GoLang Full text search go语言全文检索引擎 基于平衡二叉树+正排索引、倒排索引实现 可支持亿级数据，毫秒级查询。 使用简单，使用http接口，任何系统都可以使用。',
#   'tags': ['Go']},
#  {'time': '05_20',
#   'title': 'linux-insides',
#   'text': 'A little bit about a linux kernel',
#   'tags': ['Python']},
#  {'time': '05_20',
#   'title': 'tetragon',
#   'text': 'eBPF-based Security Observability and Runtime Enforcement',
#   'tags': ['C']},
#  {'time': '05_20',
#   'title': 'gin',
#   'text': 'Gin is a HTTP web framework written in Go (Golang). It features a Martini-like API with much better performance -- up to 40 times faster. If you need smashing performance, get yourself some Gin.',
#   'tags': ['Go']},
#  {'time': '05_20', 'title': 'Runestone', 'text': '', 'tags': ['C']},
#  {'time': '05_20',
#   'title': 'ColossalAI',
#   'text': 'Colossal-AI: A Unified Deep Learning System for Big Model Era',
#   'tags': ['Python']},
#  {'time': '05_20',
#   'title': 'beautify-github-profile',
#   'text': 'This repository helps you to have a more beautiful and attractive github profile, and you can access a complete set of tools and guides for beautifying your github profile.',
#   'tags': []},
#  {'time': '05_20',
#   'title': 'Web-Dev-For-Beginners',
#   'text': '24 Lessons, 12 Weeks, Get Started as a Web Developer',
#   'tags': ['JavaScript']},
#  {'time': '05_20',
#   'title': 'Arma-Reforger-Samples',
#   'text': 'Modding Samples',
#   'tags': ['Standard ML']},
#  {'time': '05_20',
#   'title': 'Catch2',
#   'text': 'A modern, C++-native, test framework for unit-tests, TDD and BDD - using C++14, C++17 and later (C++11 support is in v2.x branch, and C++03 on the Catch1.x branch)',
#   'tags': ['C++']},
#  {'time': '05_20', 'title': 'computer-science', 'text': '', 'tags': []},
#  {'time': '05_20',
#   'title': 'malware_showcase',
#   'text': 'Understand the nature of malicious software with practical examples in Python.',
#   'tags': ['Python']},
#  {'time': '05_20',
#   'title': 'Python-100-Days',
#   'text': 'Python - 100天从新手到大师',
#   'tags': ['Python']},
#  {'time': '05_20', 'title': 'sql-generator', 'text': '', 'tags': ['Vue']},
#  {'time': '05_20',
#   'title': 'go-clean-template',
#   'text': 'Clean Architecture template for Golang services',
#   'tags': ['Go']},
#  {'time': '05_20',
#   'title': 'SuperRDP',
#   'text': 'Super RDPWrap',
#   'tags': ['C++']},
#  {'time': '05_20',
#   'title': 'hiring-without-whiteboards',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_20',
#   'title': 'go-cqhttp',
#   'text': 'cqhttp的golang实现，轻量、原生跨平台.',
#   'tags': ['Go']},
#  {'time': '05_20',
#   'title': 'prometheus-operator',
#   'text': 'Prometheus Operator creates/configures/manages Prometheus clusters atop Kubernetes',
#   'tags': ['Go']},
#  {'time': '05_20',
#   'title': 'Data-Science-For-Beginners',
#   'text': '10 Weeks, 20 Lessons, Data Science for All!',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_20',
#   'title': 'stackrox',
#   'text': 'The StackRox Kubernetes Security Platform performs a risk analysis of the container environment, delivers visibility and runtime alerts, and provides recommendations to proactively improve security by hardening the environment.',
#   'tags': ['Go']},
#  {'time': '05_20',
#   'title': 'Flipper',
#   'text': 'Playground (and dump) of stuff I make or modify for the Flipper Zero',
#   'tags': []},
#  {'time': '05_21',
#   'title': 'RSSAggregatorforWeb3',
#   'text': 'Bootstrapping your personal Web3 info hub from more than 500 RSS Feeds.',
#   'tags': ['Python']},
#  {'time': '05_21',
#   'title': 'run',
#   'text': '润学全球官方指定GITHUB，整理润学宗旨、纲领、理论和各类润之实例；解决为什么润，润去哪里，怎么润三大问题； 并成为新中国人的核心宗教，核心信念。',
#   'tags': []},
#  {'time': '05_21',
#   'title': 'CodeEdit',
#   'text': 'CodeEdit App for macOS – Elevate your code editing experience. Open source, free forever.',
#   'tags': ['Swift']},
#  {'time': '05_21',
#   'title': 'public-apis',
#   'text': 'A collective list of free APIs',
#   'tags': ['Python']},
#  {'time': '05_21',
#   'title': 'zhao',
#   'text': '【编程随想】整理的《太子党关系网络》，专门揭露赵国的权贵',
#   'tags': ['Python']},
#  {'time': '05_21',
#   'title': 'what-happens-when-zh_CN',
#   'text': 'What-happens-when 的中文翻译，原仓库',
#   'tags': []},
#  {'time': '05_21', 'title': 'GitHub520', 'text': '', 'tags': ['Python']},
#  {'time': '05_21',
#   'title': 'GlobalMLBuildingFootprints',
#   'text': 'Worldwide building footprints derived from satellite imagery ',
#   'tags': []},
#  {'time': '05_21',
#   'title': 'Catch2',
#   'text': 'A modern, C++-native, test framework for unit-tests, TDD and BDD - using C++14, C++17 and later (C++11 support is in v2.x branch, and C++03 on the Catch1.x branch)',
#   'tags': ['C++']},
#  {'time': '05_21', 'title': 'Runestone', 'text': '', 'tags': ['Swift']},
#  {'time': '05_21',
#   'title': 'Web-Dev-For-Beginners',
#   'text': '24 Lessons, 12 Weeks, Get Started as a Web Developer',
#   'tags': ['JavaScript']},
#  {'time': '05_21',
#   'title': 'Bandai-Namco-Research-Motiondataset',
#   'text': 'This repository provides motion datasets collected by Bandai Namco Research Inc',
#   'tags': ['Python']},
#  {'time': '05_21',
#   'title': 'Data-Science-For-Beginners',
#   'text': '10 Weeks, 20 Lessons, Data Science for All!',
#   'tags': ['Jupyter Notebook']},
#  {'time': '05_21',
#   'title': 'rustdesk',
#   'text': 'Open source virtual / remote desktop infrastructure for everyone! The open source TeamViewer alternative.',
#   'tags': ['Rust']},
#  {'time': '05_21',
#   'title': 'vrising-dedicated-server-instructions',
#   'text': 'V Rising Dedicated Server Instructions',
#   'tags': []},
#  {'time': '05_21',
#   'title': 'googleapis',
#   'text': 'Public interface definitions of Google APIs.',
#   'tags': ['Starlark']},
#  {'time': '05_21', 'title': 'computer-science', 'text': '', 'tags': []},
#  {'time': '05_21',
#   'title': 'go-clean-template',
#   'text': 'Clean Architecture template for Golang services',
#   'tags': ['Go']},
#  {'time': '05_21',
#   'title': 'Arma-Reforger-Samples',
#   'text': 'Modding Samples',
#   'tags': ['Standard ML']},
#  {'time': '05_21',
#   'title': 'vite',
#   'text': "Next generation frontend tooling. It's fast!",
#   'tags': ['TypeScript']},
#  {'time': '05_21',
#   'title': 'cartreader',
#   'text': 'A shield for the Arduino Mega that can back up video game cartridges.',
#   'tags': ['C++']},
#  {'time': '05_21',
#   'title': 'remix',
#   'text': 'Build Better Websites. Create modern, resilient user experiences with web fundamentals.',
#   'tags': ['TypeScript']},
#  {'time': '05_21',
#   'title': 'gin',
#   'text': 'Gin is a HTTP web framework written in Go (Golang). It features a Martini-like API with much better performance -- up to 40 times faster. If you need smashing performance, get yourself some Gin.',
#   'tags': ['Go']},
#  {'time': '05_21', 'title': 'vue', 'text': '', 'tags': ['TypeScript']},
#  {'time': '05_23',
#   'title': 'jakt',
#   'text': 'The Jakt Programming Language',
#   'tags': ['C++']},
#  {'time': '05_23',
#   'title': 'FairEmail',
#   'text': 'Fully featured, open source, privacy friendly email app for Android',
#   'tags': ['Java']},
#  {'time': '05_23',
#   'title': 'public-apis',
#   'text': 'A collective list of free APIs',
#   'tags': ['Python']},
#  {'time': '05_23',
#   'title': 'spacedrive',
#   'text': 'Spacedrive is an open source cross-platform file explorer, powered by a virtual distributed filesystem written in Rust.',
#   'tags': ['TypeScript']},
#  {'time': '05_23',
#   'title': 'ghidra',
#   'text': 'Ghidra is a software reverse engineering (SRE) framework',
#   'tags': ['Java']},
#  {'time': '05_23',
#   'title': 'rustdesk',
#   'text': 'Open source virtual / remote desktop infrastructure for everyone! The open source TeamViewer alternative.',
#   'tags': ['Rust']},
#  {'time': '05_23',
#   'title': '90DaysOfDevOps',
#   'text': 'This repository is my documenting repository for learning the world of DevOps. I started this journey on the 1st January 2022 and I plan to run to March 31st for a complete 90-day romp on spending an hour a day including weekends to get a foundational knowledge across a lot of different areas that make up DevOps. ',
#   'tags': ['Shell']},
#  {'time': '05_23',
#   'title': 'GitHubGraduation-2022',
#   'text': 'Join the GitHub Graduation Yearbook and "walk the stage" on June 11.',
#   'tags': ['JavaScript']},
#  {'time': '05_23',
#   'title': 'seaport',
#   'text': 'Seaport is a marketplace protocol for safely and efficiently buying and selling NFTs.',
#   'tags': ['Solidity']},
#  {'time': '05_23', 'title': 'Internships', 'text': '', 'tags': []},
#  {'time': '05_23',
#   'title': 'MagiskOnWSA',
#   'text': 'Integrate Magisk root and Google Apps (OpenGApps) into WSA (Windows Subsystem for Android)',
#   'tags': []},
#  {'time': '05_23', 'title': 'core', 'text': '', 'tags': ['Python']},
#  {'time': '05_23',
#   'title': 'build-your-own-x',
#   'text': 'Master programming by recreating your favorite technologies from scratch.',
#   'tags': []},
#  {'time': '05_23',
#   'title': 'fd',
#   'text': "A simple, fast and user-friendly alternative to 'find'",
#   'tags': ['Rust']},
#  {'time': '05_23',
#   'title': 'project_syncfusion_dashboard',
#   'text': 'This is a code repository for the corresponding YouTube video. In this tutorial we are going to build and deploy a an admin dashboard app using React.js and Syncfusion',
#   'tags': ['JavaScript']},
#  {'time': '05_23',
#   'title': 'challenge',
#   'text': '微信大赛baseline',
#   'tags': ['Python']},
#  {'time': '05_23',
#   'title': 'CodeEdit',
#   'text': 'CodeEdit App for macOS – Elevate your code editing experience. Open source, free forever.',
#   'tags': ['Swift']},
#  {'time': '05_23',
#   'title': 'NoiseTorch',
#   'text': 'Real-time microphone noise suppression on Linux.',
#   'tags': ['C']},
#  {'time': '05_23',
#   'title': 'Web-Dev-For-Beginners',
#   'text': '24 Lessons, 12 Weeks, Get Started as a Web Developer',
#   'tags': ['JavaScript']},
#  {'time': '05_23',
#   'title': 'flash-linux0.11-talk',
#   'text': '你管这破玩意叫操作系统源码 — 像小说一样品读 Linux 0.11 核心代码',
#   'tags': ['HTML']},
#  {'time': '05_23', 'title': 'computer-science', 'text': '', 'tags': []},
#  {'time': '05_23',
#   'title': 'awesome-for-beginners',
#   'text': 'A list of awesome beginners-friendly projects.',
#   'tags': []},
#  {'time': '05_23',
#   'title': 'playwright',
#   'text': 'Playwright is a framework for Web Testing and Automation. It allows testing Chromium, Firefox and WebKit with a single API. ',
#   'tags': ['TypeScript']},
#  {'time': '05_23',
#   'title': 'KaTeX',
#   'text': 'Fast math typesetting for the web.',
#   'tags': ['JavaScript']},
#  {'time': '05_24',
#   'title': 'bionic-reading',
#   'text': 'A Chrome Extension for Bionic Reading on ANY website!',
#   'tags': ['JavaScript']},
#  {'time': '05_24',
#   'title': 'jakt',
#   'text': 'The Jakt Programming Language',
#   'tags': ['Rust']},
#  {'time': '05_24',
#   'title': 'spacedrive',
#   'text': 'Spacedrive is an open source cross-platform file explorer, powered by a virtual distributed filesystem written in Rust.',
#   'tags': ['TypeScript']},
#  {'time': '05_24',
#   'title': 'rustdesk',
#   'text': 'Open source virtual / remote desktop infrastructure for everyone! The open source TeamViewer alternative.',
#   'tags': ['Rust']},
#  {'time': '05_24',
#   'title': 'public-apis',
#   'text': 'A collective list of free APIs',
#   'tags': ['Python']},
#  {'time': '05_24',
#   'title': 'MagiskOnWSA',
#   'text': 'Integrate Magisk root and Google Apps (OpenGApps) into WSA (Windows Subsystem for Android)',
#   'tags': []},
#  {'time': '05_24',
#   'title': 'coding-interview-university',
#   'text': 'A complete computer science study plan to become a software engineer.',
#   'tags': []},
#  {'time': '05_24',
#   'title': 'freeCodeCamp',
#   'text': "freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free.",
#   'tags': ['TypeScript']},
#  {'time': '05_24',
#   'title': 'GitHubGraduation-2022',
#   'text': 'Join the GitHub Graduation Yearbook and "walk the stage" on June 11.',
#   'tags': ['JavaScript']},
#  {'time': '05_24', 'title': 'sherlock', 'text': '', 'tags': ['Python']},
#  {'time': '05_24',
#   'title': 'PositronV3',
#   'text': 'A upside-down, fast, portable, and compact 3D printer',
#   'tags': []},
#  {'time': '05_24',
#   'title': 'seaport',
#   'text': 'Seaport is a marketplace protocol for safely and efficiently buying and selling NFTs.',
#   'tags': ['Solidity']},
#  {'time': '05_24',
#   'title': 'tech-coops',
#   'text': 'A list of tech coops and resources concerning tech coops and worker owned cooperatives in general.',
#   'tags': []},
#  {'time': '05_24',
#   'title': 'project_syncfusion_dashboard',
#   'text': 'This is a code repository for the corresponding YouTube video. In this tutorial we are going to build and deploy a an admin dashboard app using React.js and Syncfusion',
#   'tags': ['JavaScript']},
#  {'time': '05_24',
#   'title': 'lossless-cut',
#   'text': 'The swiss army knife of lossless video/audio editing',
#   'tags': ['JavaScript']},
#  {'time': '05_24',
#   'title': 'CVE-2021-3929-3947',
#   'text': 'Recursive MMIO VM Escape PoC',
#   'tags': ['C']},
#  {'time': '05_24',
#   'title': 'iptv',
#   'text': 'Collection of publicly available IPTV channels from all over the world',
#   'tags': ['JavaScript']},
#  {'time': '05_24',
#   'title': 'Fyrox',
#   'text': '3D and 2D game engine written in Rust',
#   'tags': ['Rust']},
#  {'time': '05_24',
#   'title': 'challenge',
#   'text': '微信大赛baseline',
#   'tags': ['Python']},
#  {'time': '05_24',
#   'title': 'design-resources-for-developers',
#   'text': 'Curated list of design and UI resources from stock photos, web templates, CSS frameworks, UI libraries, tools and much more',
#   'tags': []},
#  {'time': '05_24',
#   'title': '123elf',
#   'text': 'A native port of Lotus 1-2-3 to Linux.',
#   'tags': ['C']},
#  {'time': '05_24',
#   'title': 'tech-interview-handbook',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_24', 'title': 'Internships', 'text': '', 'tags': []},
#  {'time': '05_24',
#   'title': 'bevy',
#   'text': 'A refreshingly simple data-driven game engine built in Rust',
#   'tags': ['Rust']},
#  {'time': '05_25',
#   'title': 'bionic-reading',
#   'text': 'A Chrome Extension for Bionic Reading on ANY website!',
#   'tags': ['JavaScript']},
#  {'time': '05_25',
#   'title': 'jakt',
#   'text': 'The Jakt Programming Language',
#   'tags': ['Rust']},
#  {'time': '05_25',
#   'title': 'core',
#   'text': 'GO implementation of the Terra 2.0 Protocol',
#   'tags': ['JavaScript']},
#  {'time': '05_25',
#   'title': 'project_syncfusion_dashboard',
#   'text': 'This is a code repository for the corresponding YouTube video. In this tutorial we are going to build and deploy a an admin dashboard app using React.js and Syncfusion',
#   'tags': ['JavaScript']},
#  {'time': '05_25',
#   'title': 'spacedrive',
#   'text': 'Spacedrive is an open source cross-platform file explorer, powered by a virtual distributed filesystem written in Rust.',
#   'tags': ['TypeScript']},
#  {'time': '05_25',
#   'title': 'rustdesk',
#   'text': 'Open source virtual / remote desktop infrastructure for everyone! The open source TeamViewer alternative.',
#   'tags': ['Rust']},
#  {'time': '05_25',
#   'title': 'fastjson',
#   'text': 'A fast JSON parser/generator for Java. ',
#   'tags': ['Java']},
#  {'time': '05_25',
#   'title': 'PositronV3',
#   'text': 'A upside-down, fast, portable, and compact 3D printer',
#   'tags': []},
#  {'time': '05_25',
#   'title': '123elf',
#   'text': 'A native port of Lotus 1-2-3 to Linux.',
#   'tags': ['C']},
#  {'time': '05_25', 'title': 'Mathematics-for-ML', 'text': '', 'tags': []},
#  {'time': '05_25',
#   'title': 'flash-linux0.11-talk',
#   'text': '你管这破玩意叫操作系统源码 — 像小说一样品读 Linux 0.11 核心代码',
#   'tags': ['HTML']},
#  {'time': '05_25',
#   'title': 'tech-interview-handbook',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_25',
#   'title': 'lossless-cut',
#   'text': 'The swiss army knife of lossless video/audio editing',
#   'tags': ['JavaScript']},
#  {'time': '05_25',
#   'title': 'seaport',
#   'text': 'Seaport is a marketplace protocol for safely and efficiently buying and selling NFTs.',
#   'tags': ['Solidity']},
#  {'time': '05_25', 'title': 'KR', 'text': '', 'tags': ['JavaScript']},
#  {'time': '05_25',
#   'title': 'coding-interview-university',
#   'text': 'A complete computer science study plan to become a software engineer.',
#   'tags': []},
#  {'time': '05_25',
#   'title': 'challenge',
#   'text': '微信大赛baseline',
#   'tags': ['Python']},
#  {'time': '05_25',
#   'title': 'javascript-questions',
#   'text': 'A long list of (advanced) JavaScript questions, and their explanations',
#   'tags': []},
#  {'time': '05_25',
#   'title': 'javascript-algorithms',
#   'text': '',
#   'tags': ['JavaScript']},
#  {'time': '05_25',
#   'title': 'All-Defense-Tool',
#   'text': '本项目集成了全网优秀的攻防工具项目，包含自动化利用，子域名、敏感目录、端口等扫描，各大中间件，cms漏洞利用工具以及应急响应等资料。',
#   'tags': []},
#  {'time': '05_25',
#   'title': 'GitHubGraduation-2022',
#   'text': 'Join the GitHub Graduation Yearbook and "walk the stage" on June 11.',
#   'tags': ['JavaScript']},
#  {'time': '05_25',
#   'title': 'coreutils',
#   'text': 'Cross-platform Rust rewrite of the GNU coreutils',
#   'tags': ['Rust']},
#  {'time': '05_25',
#   'title': 'MagiskOnWSA',
#   'text': 'Integrate Magisk root and Google Apps (OpenGApps) into WSA (Windows Subsystem for Android)',
#   'tags': []},
#  {'time': '05_25',
#   'title': 'redis',
#   'text': 'Type-safe Redis client for Golang',
#   'tags': ['Go']}]

# %%
# categorical_time_data :提取出time和tag
def categorical_time_data(datas):
    # 遍历数据集
    for data in datas:
        # 提取出time和程序语言标签
        time = data["time"]
        tags = data["tags"]
        for tag in tags :
            #如果标签为空，则跳过
            if tag == "":
                continue
            #每循环一次，返回一个元组(time,tag)
            #python语法糖
            yield (time,tag)

# %%
# merge_all_time_data : 将Stack Overflow和github的网站数据合并
def merge_all_time_data(all_datas):
    tag_datas={}
    #tot用于统计全部的，不论任何时间的
    tag_datas["tot"] = []
    #遍历数据结构，进行time和tag的提取
    for datas in all_datas:
        # 通过提取time和tag模块，得到time和tag数据
        for time,tag in  categorical_time_data(datas):
            # 对tot推入所有tag
            tag_datas["tot"].append(tag)
            # 将tag按时间分类
            if time not in tag_datas:
                tag_datas[time]=[]
                tag_datas[time].append(tag)
            else :
                tag_datas[time].append(tag)
    return tag_datas

# %%
def categorical_title_data(datas):
    for data in datas:
        # 提取出标题数据
        title = data["title"]
        # 将数据用jieba分词，存入列表
        list = jieba.cut(title)
        #遍历每一个分词出的单词
        for word in list:
            # 传回得到的单词
            yield word

# %%
def merge_all_title_data(all_datas):
    words = {}
    for datas in all_datas:
        #得到词频
        for word in categorical_title_data(datas):
            # 通过re库过滤 一些短的词，防止人称等无用词干扰
            # （虽然有失偏驳，但是就先这样吧）
            if re.search("^.{5,50}",word) == None:
                continue
            # 将单词通过字典存储
            if word not in words:
                words[word]=1
            else :
                words[word]+=1
    words = sorted(words.items(),key = lambda x:x[1],reverse=True)
    return words

# %%
# get_top_7 : 得到top7，以及其在每日中变化趋势
def get_top_7(data):
    # 从time_tag数据中转模块得到数据结构
    time_datas = merge_all_time_data(data)

    # 通过python自带的频率分析函数 得到每个语言的出现次数，在tot中得到前7
    dict_tmp = collections.Counter(time_datas['tot'])
    # 将得到的频率排序
    tot_rank=sorted(dict_tmp.items(),key=lambda x:x[1],reverse=True)
    top_list = [] #存放排名前7的语言元组
    time_lab=[] #存放日期标签
    top_lab=[] #存放排名前7的语言标签
    top_list_everyday = {}#存放各个日期出现的次数

    #遍历前7个出现最多的语言个数，放入上面准备好的列表中
    for index in range(7):
        top_list.append(tot_rank[index])
        top_lab.append(tot_rank[index][0])
    
    #按前7个出现最多的语言去统计得到 各个日期的数据结构
    for time,data in time_datas.items():
        if time != "tot":
            time_lab.append(time)
            # 对各个天数的日期进行频率统计
            dict_tmp = collections.Counter(time_datas[time])
            top_list_everyday[time] = []
            for name,value in dict_tmp.items():
                # 如果语言是前7的语言标签，则放入数据结构
                if name in top_lab:
                    top_list_everyday[time].append((name,value))
            # 将得到东西排个序
            top_list_everyday[time] = sorted(top_list_everyday[time],key=lambda x:x[1],reverse=True)
    #把tot也放进去
    top_list_everyday["tot"]=top_list
    #无所谓的特殊处理
    top_lab.reverse()
    #将时间标签，前7个热门语言标签，和对应的key,value返回
    return time_lab,top_lab,top_list_everyday

# %%
#数据归类操作区
all_time_lab,all_top_lab,all_top_list = get_top_7([github_today_datas,stackoverflow_datas])
github_time_lab,github_top_lab,github_top_list = get_top_7([github_today_datas])
stackoverflow_time_lab,stackoverflow_top_lab,stackoverflow_top_list = get_top_7([stackoverflow_datas])
all_title_data = merge_all_title_data([github_today_datas,stackoverflow_datas])

all_top_list
# stackoverflow_title_data = merge_all_title_data([stackoverflow_datas])
# github_title_data = merge_all_title_data([github_today_datas])
# stackoverflow_top_list
# Out:
# {'05_06': [('javascript', 22),
#   ('python', 18),
#   ('java', 9),
#   ('html', 7),
#   ('c++', 5),
#   ('reactjs', 5),
#   ('pandas', 2)],
#  '05_07': [('python', 25),
#   ('javascript', 12),
#   ('html', 11),
#   ('java', 9),
#   ('pandas', 7),
#   ('reactjs', 6),
#   ('c++', 6)],
#  '05_08': [('python', 25),
#   ('javascript', 16),
#   ('reactjs', 15),
#   ('java', 13),
#   ('c++', 5),
#   ('pandas', 5),
#   ('html', 5)],
#  '05_09': [('python', 20),
#   ('javascript', 19),
#   ('c++', 11),
#   ('reactjs', 9),
#   ('java', 8),
#   ('pandas', 4),
#   ('html', 3)],
#  '05_10': [('python', 24),
#   ('javascript', 16),
#   ('html', 10),
#   ('c++', 10),
#   ('reactjs', 8),
#   ('java', 5),
#   ('pandas', 4)],
#  '05_11': [('python', 25),
#   ('javascript', 23),
#   ('java', 9),
#   ('reactjs', 6),
#   ('html', 6),
#   ('c++', 3),
#   ('pandas', 3)],
#  '05_13': [('python', 27),
#   ('javascript', 26),
#   ('html', 10),
#   ('reactjs', 7),
#   ('java', 6),
#   ('pandas', 5),
#   ('c++', 3)],
#  '05_14': [('python', 19),
#   ('javascript', 17),
#   ('java', 8),
#   ('html', 7),
#   ('reactjs', 6),
#   ('c++', 4),
#   ('pandas', 3)],
#  '05_15': [('python', 22),
#   ('javascript', 22),
#   ('c++', 16),
#   ('pandas', 7),
#   ('java', 6),
#   ('html', 4),
#   ('reactjs', 3)],
#  '05_16': [('python', 22),
#   ('javascript', 17),
#   ('java', 11),
#   ('pandas', 9),
#   ('c++', 6),
#   ('reactjs', 4),
#   ('html', 4)],
#  '05_17': [('python', 20),
#   ('javascript', 16),
#   ('c++', 8),
#   ('html', 8),
#   ('java', 7),
#   ('reactjs', 6),
#   ('pandas', 3)],
#  '05_18': [('python', 24),
#   ('javascript', 22),
#   ('c++', 7),
#   ('reactjs', 7),
#   ('java', 5),
#   ('pandas', 4),
#   ('html', 4)],
#  '05_19': [('python', 22),
#   ('javascript', 16),
#   ('java', 12),
#   ('html', 9),
#   ('c++', 7),
#   ('reactjs', 4),
#   ('pandas', 2)],
#  '05_20': [('python', 27),
#   ('javascript', 10),
#   ('html', 10),
#   ('java', 9),
#   ('c++', 8),
#   ('reactjs', 6),
#   ('pandas', 5)],
#  '05_21': [('python', 23),
#   ('javascript', 11),
#   ('c++', 8),
#   ('java', 7),
#   ('html', 7),
#   ('pandas', 4),
#   ('reactjs', 3)],
#  '05_23': [('python', 27),
#   ('javascript', 18),
#   ('c++', 7),
#   ('reactjs', 7),
#   ('html', 6),
#   ('pandas', 5),
#   ('java', 5)],
#  '05_24': [('javascript', 23),
#   ('python', 19),
#   ('reactjs', 12),
#   ('html', 10),
#   ('java', 7),
#   ('pandas', 4),
#   ('c++', 3)],
#  '05_25': [('javascript', 22),
#   ('python', 20),
#   ('c++', 7),
#   ('java', 6),
#   ('pandas', 5),
#   ('reactjs', 5),
#   ('html', 3)],
#  'tot': [('python', 409),
#   ('javascript', 328),
#   ('java', 142),
#   ('html', 124),
#   ('c++', 124),
#   ('reactjs', 119),
#   ('pandas', 81)]}

# %%
def make_bar_3d_data(time_lab,top_lab,top_list):
    bar_3d_data = []
    for time,list in top_list.items():
        if time in time_lab:
            i = time_lab.index(time)
            for name,value in list:
                j = top_lab.index(name)
                z = value
                bar_3d_data.append([i,j,z])
    return bar_3d_data

# %%
def make_line_data(time_lab,top_lab,top_list):
    line_data = {}
    for lab in top_lab:
        line_data[lab]=[]
        for time in time_lab:
            flag = True
            for data in top_list[time]:
                # print(data)
                if data[0] == lab:
                    flag = False
                    line_data[lab].append(data[1])
            if flag :
                line_data[lab].append(0)
    return line_data

# %%
def draw_bar_3d(all_time_lab,all_top_lab,all_top_list,title):
    datas = make_bar_3d_data(all_time_lab,all_top_lab,all_top_list)
    bar = (
    Bar3D(init_opts=opts.InitOpts(width="1400px", height="600px"))
    .add(
        series_name="",
        data=datas,
        xaxis3d_opts=opts.Axis3DOpts(type_="category", data=all_time_lab),
        yaxis3d_opts=opts.Axis3DOpts(type_="category", data=all_top_lab),
        zaxis3d_opts=opts.Axis3DOpts(type_="value"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title=title),
        visualmap_opts=opts.VisualMapOpts(
            max_=20,
            range_color=[
                "#313695",
                "#4575b4",
                "#74add1",
                "#abd9e9",
                "#e0f3f8",
                "#ffffbf",
                "#fee090",
                "#fdae61",
                "#f46d43",
                "#d73027",
                "#a50026",
            ],
        )
    )
    )
    return bar

# %%
def draw_line(time_lab,top_lab,top_list,title):
    datas = make_line_data(time_lab,top_lab,top_list)
    line = (
    Line(init_opts=opts.InitOpts(width="1600px", height="800px"))
    .add_xaxis(time_lab)
    .add_yaxis(top_lab[0], datas[top_lab[0]])
    .add_yaxis(top_lab[1], datas[top_lab[1]])
    .add_yaxis(top_lab[2], datas[top_lab[2]])
    .add_yaxis(top_lab[3], datas[top_lab[3]])
    .add_yaxis(top_lab[4], datas[top_lab[4]])
    .add_yaxis(top_lab[5], datas[top_lab[5]])
    .add_yaxis(top_lab[6], datas[top_lab[6]])
    .set_global_opts(
        title_opts=opts.TitleOpts(title=title),
        visualmap_opts=opts.VisualMapOpts(type_="size", max_=30, min_=0),
        )

    )
    return line

# %%
def draw_Scatter(time_lab,top_lab,top_list,title):
    datas = make_line_data(time_lab,top_lab,top_list)
    line = (
    Scatter(init_opts=opts.InitOpts(width="1600px", height="800px"))
    .add_xaxis(time_lab)
    .add_yaxis(top_lab[0], datas[top_lab[0]],
            label_opts=opts.LabelOpts(
            formatter=JsCode(
                "function(params){return params.value[1] +' : '+ '"+top_lab[0]+"';}"
            )
        ),
    )
    .add_yaxis(top_lab[1], datas[top_lab[1]],
                label_opts=opts.LabelOpts(
            formatter=JsCode(
                "function(params){return params.value[1] +' : '+ '"+top_lab[1]+"';}"
            )
        ),
    )
    .add_yaxis(top_lab[2], datas[top_lab[2]],
                label_opts=opts.LabelOpts(
            formatter=JsCode(
                "function(params){return params.value[1] +' : '+ '"+top_lab[2]+"';}"
            )
        ),
    )
    .add_yaxis(top_lab[3], datas[top_lab[3]],
                label_opts=opts.LabelOpts(
            formatter=JsCode(
                "function(params){return params.value[1] +' : '+ '"+top_lab[3]+"';}"
            )
        ),
    )
    .add_yaxis(top_lab[4], datas[top_lab[4]],
                label_opts=opts.LabelOpts(
            formatter=JsCode(
                "function(params){return params.value[1] +' : '+ '"+top_lab[4]+"';}"
            )
        ),
    )
    .add_yaxis(top_lab[5], datas[top_lab[5]],
                label_opts=opts.LabelOpts(
            formatter=JsCode(
                "function(params){return params.value[1] +' : '+ '"+top_lab[5]+"';}"
            )
        ),
    )
    .add_yaxis(top_lab[6], datas[top_lab[6]],
                label_opts=opts.LabelOpts(
            formatter=JsCode(
                "function(params){return params.value[1] +' : '+ '"+top_lab[6]+"';}"
            )
        ),
    )
    .set_global_opts(
            tooltip_opts=opts.TooltipOpts(
            formatter=JsCode(
                "function (params) {return params.name + ' : ' + '"+top_lab[1]+"';}"
            )
        ),
        title_opts=opts.TitleOpts(title=title),
        visualmap_opts=opts.VisualMapOpts(type_="size", max_=0, min_=30),
        )

    )
    return line

# %%
def draw_pie(top_list,title):
    pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="800px", bg_color="#ffffff"))
    .add(
        series_name="数据",
        data_pair=top_list,
        rosetype="radius",
        radius="55%",
        center=["50%", "50%"],
        label_opts=opts.LabelOpts(is_show=False, position="center"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title=title,
            pos_left="center",
            pos_top="20",
            title_textstyle_opts=opts.TextStyleOpts(color="#000000"),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
        label_opts=opts.LabelOpts(color="rgba(0, 0, 0, 0.3)"),
    )
    )
    return pie

# %%
def draw_pie_tab(datas,title):
    pie_datas={}
    for name,value in datas.items():
        pie = draw_pie(value,title+" "+name+" 饼状图")
        pie_datas[name]=pie
    tab = Tab()
    for name,chart in pie_datas.items():
        tab.add(chart,name)
    return tab

# %%
def draw_wordcloud(words,title):
    cloud = (
    WordCloud(init_opts=opts.InitOpts(width="1000px", height="500px"))
    .add("", words, word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title=title))
    )
    return cloud

# %%
#图像绘制区
cloud = draw_wordcloud(all_title_data,"聚合标题词云图")
github_tab = draw_pie_tab(github_top_list,"github ")
stackoverflow_tab = draw_pie_tab(stackoverflow_top_list," stackoverflow ")
bar_3d = draw_bar_3d(all_time_lab,all_top_lab,all_top_list,title="聚合趋势3D柱状图")
github_line = draw_line(github_time_lab,github_top_lab,github_top_list,title="github排行榜语言趋势折线图")
stackoverflow_line = draw_line(stackoverflow_time_lab,stackoverflow_top_lab,stackoverflow_top_list,title="StackOverflow排行榜语言趋势折线图")

# %%
cloud.render("cloud.html")
github_tab.render("github_tab.html")
stackoverflow_tab.render("stackoverflow_tab.html")
github_line.render("github_line.html")
stackoverflow_line.render("stackoverflow_line.html")
bar_3d.render("bar_3d.html")
# Out:
# 'e:\\项目经验笔记\\crawly_end\\bar_3d.html'
